# %%
# Load data
import pandas as pd
pd.set_option('display.max_columns', 100)
train = pd.read_csv("../data/interim/train.csv")
dev = pd.read_csv("../data/interim/dev.csv")
test = pd.read_csv("../data/interim/test.csv")
df = pd.read_csv("../data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv")
assert df.shape[0] == train.shape[0] + dev.shape[0] + test.shape[0]
train.shape, dev.shape, test.shape, df.shape
# Out:
# ((4225, 20), (1409, 20), (1409, 20), (7043, 21))

# %%
# Same ratio of target values
print(" ", train['churn'].value_counts(normalize=True).values, "\n ", \
      dev['churn'].value_counts(normalize=True).values, "\n ", \
      test['churn'].value_counts(normalize=True).values)
# Out:
#   [0.73467456 0.26532544]
#   [0.73456352 0.26543648]
#   [0.73456352 0.26543648]

# %%
train.head()
# Out:
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               1      No         No      67           Yes
# 1  Female               0      No         No      23           Yes
# 2  Female               0     Yes        Yes      64           Yes
# 3  Female               0     Yes         No      72           Yes
# 4  Female               0     Yes         No      56           Yes
#
#   multiple_lines internet_service      online_security        online_backup  \
# 0            Yes              DSL                   No                  Yes
# 1            Yes      Fiber optic                   No                   No
# 2            Yes      Fiber optic                   No                  Yes
# 3            Yes               No  No internet service  No internet service
# 4            Yes               No  No internet service  No internet service
#
#      device_protection         tech_support         streaming_tv  \
# 0                   No                   No                   No
# 1                   No                   No                  Yes
# 2                  Yes                   No                   No
# 3  No internet service  No internet service  No internet service
# 4  No internet service  No internet service  No internet service
#
#       streaming_movies        contract paperless_billing  \
# 0                   No  Month-to-month                No
# 1                  Yes  Month-to-month               Yes
# 2                  Yes        One year               Yes
# 3  No internet service        Two year               Yes
# 4  No internet service        One year                No
#
#             payment_method  monthly_charges  total_charges  churn
# 0         Electronic check            54.90        3725.50      0
# 1         Electronic check            93.50        2341.55      0
# 2         Electronic check            92.85        5980.75      0
# 3  Credit card (automatic)            24.15        1776.45      0
# 4         Electronic check            24.30        1261.70      0

# %%
for cat_column in train.select_dtypes('O').columns:
    print("-------", cat_column, "-------\n", train[cat_column].value_counts(), "\n", "-"*(len(cat_column)+15), "\n")
# Out:
# ------- gender -------
#  Male      2151
# Female    2074
# Name: gender, dtype: int64
#  ---------------------
#
# ------- partner -------
#  No     2180
# Yes    2045
# Name: partner, dtype: int64
#  ----------------------
#
# ------- dependents -------
#  No     2974
# Yes    1251
# Name: dependents, dtype: int64
#  -------------------------
#
# ------- phone_service -------
#  Yes    3834
# No      391
# Name: phone_service, dtype: int64
#  ----------------------------
#
# ------- multiple_lines -------
#  No                  2027
# Yes                 1807
# No phone service     391
# Name: multiple_lines, dtype: int64
#  -----------------------------
#
# ------- internet_service -------
#  Fiber optic    1890
# DSL            1417
# No              918
# Name: internet_service, dtype: int64
#  -------------------------------
#
# ------- online_security -------
#  No                     2114
# Yes                    1193
# No internet service     918
# Name: online_security, dtype: int64
#  ------------------------------
#
# ------- online_backup -------
#  No                     1851
# Yes                    1456
# No internet service     918
# Name: online_backup, dtype: int64
#  ----------------------------
#
# ------- device_protection -------
#  No                     1861
# Yes                    1446
# No internet service     918
# Name: device_protection, dtype: int64
#  --------------------------------
#
# ------- tech_support -------
#  No                     2101
# Yes                    1206
# No internet service     918
# Name: tech_support, dtype: int64
#  ---------------------------
#
# ------- streaming_tv -------
#  No                     1661
# Yes                    1646
# No internet service     918
# Name: streaming_tv, dtype: int64
#  ---------------------------
#
# ------- streaming_movies -------
#  No                     1661
# Yes                    1646
# No internet service     918
# Name: streaming_movies, dtype: int64
#  -------------------------------
#
# ------- contract -------
#  Month-to-month    2336
# Two year          1013
# One year           876
# Name: contract, dtype: int64
#  -----------------------
#
# ------- paperless_billing -------
#  Yes    2535
# No     1690
# Name: paperless_billing, dtype: int64
#  --------------------------------
#
# ------- payment_method -------
#  Electronic check             1409
# Mailed check                  983
# Bank transfer (automatic)     929
# Credit card (automatic)       904
# Name: payment_method, dtype: int64
#  -----------------------------

# %%
# Out:
# Index(['gender', 'partner', 'dependents', 'phone_service', 'multiple_lines',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies',
#        'contract', 'paperless_billing', 'payment_method'],
#       dtype='object')
